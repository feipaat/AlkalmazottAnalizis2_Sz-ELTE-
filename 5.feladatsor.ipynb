% %% [markdown]
% ## <center>5. Feladatsor</center>
%
% <img src="profschedule.gif" width="700">
% <br>
% <br>
% <b>1.feladat.</b> Írjunk általános implicit Euler programot $a,b,f,y0,N$ input és $h,t,y$ output paraméterekkel. Használjuk a MATLAB beépített fsolve parancsát! A programot alkalmazzuk az előző feladatsor Lotka-Volterra feladatára és reprodukáljuk az ottani ábrákat is!
% <br>

% %% [markdown]
% <b>2.feladat.</b> Elemezzük a kapott impeulersys.m fájlt és futtassuk Lotka-Volterra esetén!
%
%
% <br>

% %%
% Out:
% it =  4

% %% [markdown]
% <b>3.feladat.</b> Döntsük el, hogy az órán tanult módszerek A-stabil módszerek-e vagy sem!

% %%
%Explicit Euler
clf;
[X,Y] = meshgrid(linspace(-5,5), linspace(-5,5));
Z = X+Y*1i;
phi = 1+Z;
contourf(X,Y,1-abs(phi), [0 0], 'LineWidth', 1);
set(gca,'FontSize', 10, 'CLim', [0 1]);
colormap([.1 .5 .3; 0 0 0; 1 1 1]);
hold on;
plot([-5 5], [0 0], '--k', 'LineWidth', 1);
plot([0 0], [-5 5], '--k', 'LineWidth', 1);
axis('square');
title('Abszolut stabilitasi tartomany, EE')

% %% [markdown]
% <br>
% <b>4.feladat.</b> Írjunk általános Adams--Bashfort 2 programot $a,b,f,y0,N$ input és $h,t,y$ output paraméterekkel úgy, hogy RK2 módszerrel módszerrel indítjuk meg a kétlépéses módszert.  A programot alkalmazzuk az előző feladatsor Lotka-Volterra feladatára és reprodukáljuk az ottani ábrákat is!
% <br>
